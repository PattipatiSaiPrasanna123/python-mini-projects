# %% [markdown]
# <a href="https://colab.research.google.com/github/PattipatiSaiPrasanna123/python-mini-projects/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
   a1.append(random.randint(0,100))
   a2. append(random.randint(50,70))
   a3. append(random.randint(10,20))
   a4. append(random.randint(5,10))
   a5. append(random.randint(20,80))

# %%
df={
   'grade':a1,
   'weight':a2,
   'friends':a3,
   'cousins':a4,
   'project':a5
   }

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  project
# 0       53      63       16        9       71
# 1       90      51       13        5       45
# 2       69      69       10        8       38
# 3       21      65       18        9       44
# 4       74      55       12        9       67
# ..     ...     ...      ...      ...      ...
# 995     68      60       11        8       49
# 996     33      59       10        5       42
# 997     55      65       16        8       60
# 998     19      69       10        8       68
# 999     12      65       10        7       30
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight     friends      cousins      project
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     47.590000    60.212000    15.08800     7.520000    50.469000
# std      29.447395     6.072391     3.25989     1.708953    17.309785
# min       0.000000    50.000000    10.00000     5.000000    20.000000
# 25%      21.000000    55.000000    12.00000     6.000000    36.000000
# 50%      46.500000    60.000000    15.00000     8.000000    51.000000
# 75%      72.000000    66.000000    18.00000     9.000000    65.000000
# max     100.000000    70.000000    20.00000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  project
# 0       53      63       16        9       71
# 3       21      65       18        9       44
# 6       25      52       19        9       29
# 7        8      60       17        8       46
# 10      17      53       20       10       22
# ..     ...     ...      ...      ...      ...
# 988      6      62       17        8       40
# 991     42      50       17        7       68
# 992     51      69       19        6       75
# 993     62      54       18        8       37
# 997     55      65       16        8       60
#
# [469 rows x 5 columns]

# %%
grade50=df1['grade']>15

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  project
# 0       53      63       16        9       71
# 1       90      51       13        5       45
# 2       69      69       10        8       38
# 3       21      65       18        9       44
# 4       74      55       12        9       67
# ..     ...     ...      ...      ...      ...
# 994     19      52       15        5       53
# 995     68      60       11        8       49
# 996     33      59       10        5       42
# 997     55      65       16        8       60
# 998     19      69       10        8       68
#
# [818 rows x 5 columns]

# %%
df1[friend15 & grade50].describe()
# Out:
#             grade      weight     friends     cousins     project
# count  382.000000  382.000000  382.000000  382.000000  382.000000
# mean    55.290576   59.973822   18.065445    7.471204   50.897906
# std     24.573034    6.115197    1.444842    1.621042   17.323464
# min     16.000000   50.000000   16.000000    5.000000   20.000000
# 25%     35.000000   54.000000   17.000000    6.000000   36.000000
# 50%     54.500000   60.000000   18.000000    8.000000   52.000000
# 75%     76.750000   66.000000   19.000000    9.000000   65.000000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
df1[friend15 & grade50]['friends']
# Out:
# 0      16
# 3      18
# 6      19
# 10     20
# 15     17
#        ..
# 987    17
# 991    17
# 992    19
# 993    18
# 997    16
# Name: friends, Length: 382, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x='grade', y='project',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade', y='project',kind='pie')
plt.xlabel('x Axis')
plt.ylabel('y Axis')
plt.legend('Test Data')
plt.show()

# %%
from matplotlib import pyplot as lib

# %%
fdf= df1[friend15 & grade50]

# %%
df1
# Out:
#      grade  weight  friends  cousins  project
# 0       53      63       16        9       71
# 1       90      51       13        5       45
# 2       69      69       10        8       38
# 3       21      65       18        9       44
# 4       74      55       12        9       67
# ..     ...     ...      ...      ...      ...
# 995     68      60       11        8       49
# 996     33      59       10        5       42
# 997     55      65       16        8       60
# 998     19      69       10        8       68
# 999     12      65       10        7       30
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('Feb6TestData.csv')
